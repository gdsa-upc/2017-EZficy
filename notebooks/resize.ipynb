# %%
# Reads an image from disk and scales and crops to match a target resolution and aspect ratio.
from scipy import misc
import matplotlib.pyplot as plt

import cv2
import matplotlib.pyplot as lt
import sys

# guardamos la imagen seleccionada en la variable img
img = cv2.imread('C:\Users\Jean\Desktop\UPC\GDSA\mercat_independencia\IMG_3294.JPG', 1)

print(img.shape)
plt.imshow(img)
plt.show()

img_resized = misc.imresize(img, 500.0 / len(img), interp='nearest', mode=None)
dims = img_resized.shape
print(dims)
plt.imshow(img_resized)
plt.show()

img_resized_cropped = img_resized[0:500,(dims[1]/2 - 333):(dims[1]/2 + 333)]
print(img_resized_cropped.shape)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) 
plt.show()

#plt.imshow(img_resized_cropped)
#plt.show()
# Out:
# (2448L, 3264L, 3L)
# (500L, 666L, 3L)
# (500L, 666L, 3L)
